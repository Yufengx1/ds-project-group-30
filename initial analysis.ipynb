# %%
import pandas as pd

# %%
df = pd.read_excel("Cleansing the data/result clean data.xlsx")

# %%
df
# Out:
#        predicted_id New_Audit_id  Audit_ID                    Facility_ID  \
# 0        289713_1_1     289713_1    289713                Whispered Okapi
# 1        289713_1_7     289713_1    289713                Whispered Okapi
# 2       289713_1_19     289713_1    289713                Whispered Okapi
# 3       289713_1_20     289713_1    289713                Whispered Okapi
# 4       289713_1_21     289713_1    289713                Whispered Okapi
# ...             ...          ...       ...                            ...
# 43471  368829_2_464     368829_2    368829  Klutzy English Cocker Spaniel
# 43472  368829_2_465     368829_2    368829  Klutzy English Cocker Spaniel
# 43473  368829_2_466     368829_2    368829  Klutzy English Cocker Spaniel
# 43474  368829_2_467     368829_2    368829  Klutzy English Cocker Spaniel
# 43475  368829_2_468     368829_2    368829  Klutzy English Cocker Spaniel
#
#       Status     Auditor1      Auditor2 Auditor3    Au date  \
# ...
